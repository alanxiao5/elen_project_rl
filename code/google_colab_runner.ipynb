# %%
from google.colab import drive

import os
def check_and_reconnect_drive():
    try:
        # Check if Google Drive is still connected
        os.listdir('/content/drive')
    except:
        # If not, reconnect it
        from google.colab import drive
        drive.mount('/content/drive', force_remount=True)

# Then call this function every so often in your main script
check_and_reconnect_drive()

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Wed Dec 18 09:35:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import sys
import os

py_file_location = "/content/drive/MyDrive/Colab Notebooks/elen_project/alphagen"
sys.path.append(os.path.abspath(py_file_location))

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/elen_project/alphagen
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/elen_project/alphagen
# /content/drive/MyDrive/Colab Notebooks/elen_project/alphagen

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/elen_project/alphagen

# %%
# !pip install --upgrade  cython
# !git clone https://github.com/microsoft/qlib.git
# !pip install ./qlib
# Out:
# ...
# fatal: destination path 'qlib' already exists and is not an empty directory.
# Processing ./qlib
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyqlib: filename=pyqlib-0.9.5.99-cp310-cp310-linux_x86_64.whl size=1036591 sha256=4ee8f08d10be388a26e534e113fa2c8454901a899b297b8057fd5f26344a0dbd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yd43alu5/wheels/ab/ff/77/5ae57766fdada1856179c158fcf5eb45e9c78b2d5683d7c559
# Successfully built pyqlib
# ...
#   Attempting uninstall: pyqlib
#     Found existing installation: pyqlib 0.9.5.99
#     Uninstalling pyqlib-0.9.5.99:
#       Successfully uninstalled pyqlib-0.9.5.99
# ...

# %%
# !pip install -r requirements_google_colab.txt

# %%
from train_model import main

# %%
reward_shaping = 'NO_REWARD_SHAPING'
name_of_the_folder = fr"/content/drive/MyDrive/Colab Notebooks/elen_project/rw_{reward_shaping}/tb/log/new_all_10_5_20241212125448_1"

# %%
main('NO_REWARD_SHAPING',20, 200000, 30)
# Out:
# [3479:MainThread](2024-12-18 09:36:18,636) INFO - qlib.Initialization - [config.py:416] - default_conf: client.
# INFO:qlib.Initialization:default_conf: client.
# [3479:MainThread](2024-12-18 09:36:19,089) INFO - qlib.Initialization - [__init__.py:74] - qlib successfully initialized based on client settings.
# INFO:qlib.Initialization:qlib successfully initialized based on client settings.
# [3479:MainThread](2024-12-18 09:36:19,096) INFO - qlib.Initialization - [__init__.py:76] - data_path={'__DEFAULT_FREQ': PosixPath('/content/drive/MyDrive/Colab Notebooks/elen_project/.qlib/qlib_data/custom_us_data2')}
# INFO:qlib.Initialization:data_path={'__DEFAULT_FREQ': PosixPath('/content/drive/MyDrive/Colab Notebooks/elen_project/.qlib/qlib_data/custom_us_data2')}

# %%
# %load_ext tensorboard
# %tensorboard --logdir=name_of_the_folder
